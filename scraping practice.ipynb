# %%
from urllib.request import urlopen
html = urlopen('http://www.pythonscraping.com/pages/page1.html')
print(html.read())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5468\1243502397.py in <module>
#       1 from urllib.request import urlopen
# ----> 2 html = urlopen('http://www.pythonscraping.com/pages/page1.html')
#       3 print(html.read())
#
# c:\Users\PC\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# c:\Users\PC\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#     525         return response
#
# c:\Users\PC\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     630         # request was successfully received, understood, and accepted.
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#     634
#
# c:\Users\PC\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     553             http_err = 0
#     554         args = (dict, proto, meth_name) + args
# --> 555         result = self._call_chain(*args)
#     556         if result:
#     557             return result
#
# c:\Users\PC\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# c:\Users\PC\anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     745         fp.close()
#     746
# --> 747         return self.parent.open(new, timeout=req.timeout)
#     748
#     749     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# c:\Users\PC\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# c:\Users\PC\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# c:\Users\PC\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# c:\Users\PC\anaconda3\lib\urllib\request.py in http_open(self, req)
#    1373
#    1374     def http_open(self, req):
# -> 1375         return self.do_open(http.client.HTTPConnection, req)
#    1376
#    1377     http_request = AbstractHTTPHandler.do_request_
#
# c:\Users\PC\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1348             except OSError as err: # timeout error
#    1349                 raise URLError(err)
# -> 1350             r = h.getresponse()
#    1351         except:
#    1352             h.close()
#
# c:\Users\PC\anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# c:\Users\PC\anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# c:\Users\PC\anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# c:\Users\PC\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\pc\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\pc\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pc\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
html = urlopen('http://www.pythonscraping.com/pages/page1.html')
page = BeautifulSoup(html.read(), "lxml")
print(page)
# Out:
# <html>
# <head>
# <title>A Useful Page</title>
# </head>
# <body>
# <h1>An Interesting Title</h1>
# <div>
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
# </div>
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
BookName = []
star = []
cost = []
for i in range(1, 51):
    url = f"https://books.toscrape.com/catalogue/page-{i}.html"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    ol = soup.find('ol')
    articles = soup.find_all('article', class_ = "product_pod")
    for article in articles:
        image = article.find("img")
        title = image.attrs["alt"]
        rating = article.find('p')
        rating = rating['class'][1]
        price = article.find('p', class_ = 'price_color').text
        BookName.append(title)
        star.append(rating)
        cost.append(price)
data = {"Book Name" : BookName, "Rating" : star, "Price" : cost}
df = pd.DataFrame(data)

# %%
df.head(5)
# Out:
#                                Book Name Rating   Price
# 0                   A Light in the Attic  Three  £51.77
# 1                     Tipping the Velvet    One  £53.74
# 2                             Soumission    One  £50.10
# 3                          Sharp Objects   Four  £47.82
# 4  Sapiens: A Brief History of Humankind   Five  £54.23

# %%
print(article)
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="1000-places-to-see-before-you-die_1/index.html"><img alt="1,000 Places to See Before You Die" class="thumbnail" src="../media/cache/d7/0f/d70f7edd92705c45a82118c3ff6c299d.jpg"/></a>
# </div>
# <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="1000-places-to-see-before-you-die_1/index.html" title="1,000 Places to See Before You Die">1,000 Places to See ...</a></h3>
# <div class="product_price">
# <p class="price_color">£26.08</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from urllib.request import urlopen
import re
Hotel_Name = []
Location = []
Address = []
Cost = []
Property_type = []
Likes = []
Rating = []
Review = []

for i in range(1, 341):
    url = f"https://hotels.ng/hotels-in-lagos/{i}"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    wrap = soup.find("div", itemtype="http://schema.org/ItemList")
    container = wrap.find_all('div', class_ = "listing-hotels")
    print(f"Page {i} done")
    for value in container:
        div_a = value.find("div", class_ ="col-xs-8 listing-hotels-details")
        name = div_a.find('div', class_ = "listing-hotels-details-property").find('h2').text
        city = value.find("p", class_ = "listing-hotels-address color-dark hidden-md hidden-lg").find("a").text
        address = value.find("p", class_ = "listing-hotels-address color-dark hidden-md hidden-lg").text
        div_b = value.find('div', class_ = "col-xs-4 listing-hotels-prices")
        try:
            p = div_b.find("p", class_ = "listing-hotels-prices-discount")
            price = p.text.split("\n")[0]
        except:
            price = "NA"
        try:
            div = value.find('div', class_ = "listing-hotels-rating-box")
            p = div.find('p', class_ = "listing-hotels-rating")
            rating = p.find('span', class_ = "bkgrnd-v-good").text
            review = div.find('p', class_ = "listing-hotels-rating-number").text
        except:
            rating = "NA"
            review = "NA"
        property_type = value.find("div", class_ = "listing-hotels-details-property").text
        property_type = property_type.strip("\n")
        div_c = value.find("div", class_ = "listing-hotels-likes").text
        likes = "".join(re.findall(r'\d+', div_c))
        Hotel_Name.append(name)
        Location.append(city)
        Address.append(address)
        Cost.append(price)
        Property_type.append(property_type)
        Likes.append(likes)
        Review.append(review)
        Rating.append(rating)
    
hotel = {
    "Hotel_Name":Hotel_Name,
    "Location":Location,
    "Address":Address,
    "Cost":Cost,
    "Property_type":Property_type,
    "Likes":Likes,
    "Rating":Rating,
    "Review":Review
    }
df = pd.DataFrame(hotel)
# Out:
# Page 1 done
# Page 2 done
# Page 3 done
# Page 4 done
# Page 5 done
# Page 6 done
# Page 7 done
# Page 8 done
# Page 9 done
# Page 10 done
# Page 11 done
# Page 12 done
# Page 13 done
# Page 14 done
# Page 15 done
# Page 16 done
# Page 17 done
# Page 18 done
# Page 19 done
# Page 20 done
# Page 21 done
# Page 22 done
# Page 23 done
# Page 24 done
# Page 25 done
# Page 26 done
# Page 27 done
# Page 28 done
# Page 29 done
# Page 30 done
# Page 31 done
# Page 32 done
# Page 33 done
# Page 34 done
# Page 35 done
# Page 36 done
# Page 37 done
# Page 38 done
# Page 39 done
# Page 40 done
# Page 41 done
# Page 42 done
# Page 43 done
# Page 44 done
# Page 45 done
# Page 46 done
# Page 47 done
# Page 48 done
# Page 49 done
# Page 50 done
# Page 51 done
# Page 52 done
# Page 53 done
# Page 54 done
# Page 55 done
# Page 56 done
# Page 57 done
# Page 58 done
# Page 59 done
# Page 60 done
# Page 61 done
# Page 62 done
# Page 63 done
# Page 64 done
# Page 65 done
# Page 66 done
# Page 67 done
# Page 68 done
# Page 69 done
# Page 70 done
# Page 71 done
# Page 72 done
# Page 73 done
# Page 74 done
# Page 75 done
# Page 76 done
# Page 77 done
# Page 78 done
# Page 79 done
# Page 80 done
# Page 81 done
# Page 82 done
# Page 83 done
# Page 84 done
# Page 85 done
# Page 86 done
# Page 87 done
# Page 88 done
# Page 89 done
# Page 90 done
# Page 91 done
# Page 92 done
# Page 93 done
# Page 94 done
# Page 95 done
# Page 96 done
# Page 97 done
# Page 98 done
# Page 99 done
# Page 100 done
# Page 101 done
# Page 102 done
# Page 103 done
# Page 104 done
# Page 105 done
# Page 106 done
# Page 107 done
# Page 108 done
# Page 109 done
# Page 110 done
# Page 295 done
# Page 296 done
# Page 297 done
# Page 298 done
# Page 299 done
# Page 300 done
# Page 301 done
# Page 302 done
# Page 303 done
# Page 304 done
# Page 305 done
# Page 306 done
# Page 307 done
# Page 308 done
# Page 309 done
# Page 310 done
# Page 311 done
# Page 312 done
# Page 313 done
# Page 314 done
# Page 315 done
# Page 316 done
# Page 317 done
# Page 318 done
# Page 319 done
# Page 320 done
# Page 321 done
# Page 322 done
# Page 323 done
# Page 324 done
# Page 325 done
# Page 326 done
# Page 327 done
# Page 328 done
# Page 329 done
# Page 330 done
# Page 331 done
# Page 332 done
# Page 333 done
# Page 334 done
# Page 335 done
# Page 336 done
# Page 337 done
# Page 338 done
# Page 339 done
# Page 340 done

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3395 entries, 0 to 3394
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hotel_Name     3395 non-null   object
#  1   Location       3395 non-null   object
#  2   Address        3395 non-null   object
#  3   Cost           3395 non-null   object
#  4   Property_type  3395 non-null   object
#  5   Likes          3395 non-null   object
#  6   Rating         3395 non-null   object
#  7   Review         3395 non-null   object
# dtypes: object(8)
# memory usage: 212.3+ KB

# %%
df.sample(50)
# Out:
#                                              Hotel_Name         Location  \
# 2752        1 Bedroom Flat For Short Let In V.I-1391878  Victoria Island
# 1285                                       Tablos Hotel
# 84                                   Travel House Lekki            Lekki
# 1879                                 Bubble Guest House          Badagry
# 982                          Aregbesola Executive Hotel             Yaba
# 2947                        King Solomon Hotel Resorts
# 319                          The Wheatbaker Hotel Lagos            Ikoyi
# 1873                                 Shado Royal Hotel             Isolo
# 894                       A- Quality Lodging And Suites         Surulere
# 2180                      Eleshin Dudu Hotel And Suites
# 1467                                    RTT Guest House            Lekki
# 2224                                  Savanah Extension            Apapa
# 2243                                      Zenith Hotels         Surulere
# 1088                                     Richbeth Hotel            Ikeja
# 936                                          MADIBA HUB            Lekki
# 2439                                         Uptown Inn         Alagbado
# 2328                                Shasta Golden Hotel             Ajah
# 2234            ATLANTIC GUEST HOUSE, VICTORIA ISLAND 2  Victoria Island
# 782                                  SBI Hotels Limited             Ajah
# 2081                          Majaland Hotel And Suites
# 3361                       Prestcruise Waterfront Hotel    Lekki Phase 1
# 1714              Air Wing View Furnished Apartment Ltd         Maryland
# 665                                     West Brom Hotel             Ketu
# 1562                       The Executive Spot And Hotel            Ikoyi
# 2556                     Three Bedroom Luxury Apartment  Victoria Island
# 1913                              Dee Johnson Guest Inn             Egbe
# 1086                                 Atlantic Hotel LTD            Ikeja
# 705                                   El Al Court Hotel  Victoria Island
# 961                                   D Sky Holiday Inn            Lekki
# 1959                              Lekki Grandview Hotel            Lekki
# 2580                         LUXURY CHARMING APARTMENTS
# 1474                      Tobby Royal Suites Apartment             Ikeja
# 3060                                     Backbone Hotel            Lekki
# 2904                        Serviced Mini Flat-13919207            Ikoyi
# 2795  Tastefully Furnished 1 Bedroom Apartment-13919118            Lekki
# 2033                          Cy Hotels By Trini Hotels
# 2795  Tastefully Furnished 1 Bedroom Apartment-13919118     1             NA
# 2033                          Cy Hotels By Trini Hotels     2             NA
# 185                                               Hotel  1243  7.7 Very Good
# 571                                               Hotel   564             NA
# 1831                                      Afredo Suites     4             NA
# 552                                               Hotel   309             NA
# 1352                                           Vickolas     4             NA
# 3326                              Ocean View Apartment      1             NA
# 3257                               Workclick Apartments     1             NA
# 1347                             Sunnyjoyce Guest House     4             NA
# 2023                                JD Lounge And Suite     2             NA
# 1226                          Mate Garden Hotel Limited    12             NA
# 962                                               Hotel    15             NA
# 313                                         Guest House   330             NA
# 1806                                              Hotel     6             NA
# 3199  1 Bedroom Mini Flat At Elegba Festival Road, O...     1             NA
#
#                Review
# 2752               NA
# 1285               NA
# 84    From 94 reviews
# 1879               NA
# 982                NA
# 2947               NA
# 319                NA
# 1873               NA
# 894                NA
# 2180               NA
# 1467               NA
# 2224               NA
# 2243               NA
# 1088               NA
# 936                NA
# 2439               NA
# 2328               NA
# 2234               NA
# 782    From 5 reviews
# 2081               NA
# 3361               NA
# 1714               NA
# 665    From 3 reviews
# 1562               NA
# 2556               NA
# 1913               NA
# 1086               NA
# 705                NA
# 961                NA
# 1959               NA
# 2580               NA
# 1474               NA
# 3060               NA
# 2904               NA
# 2795               NA
# 2033               NA
# 185    From 5 reviews
# 571                NA
# 1831               NA
# 552                NA
# 1352               NA
# 3326               NA
# 3257               NA
# 1347               NA
# 2023               NA
# 1226               NA
# 962                NA
# 313                NA
# 1806               NA
# 3199               NA

# %%
df = pd.read_csv("Hotels In Lagos.csv")
df.head()
# Out:
#    Unnamed: 0              Hotel_Name         Location  \
# 0           0      Casa Del Amor - VI  Victoria Island
# 1           1            Kitex Place     Lekki Phase 1
# 2           2      Ibis Lagos Airport      Ajao Estate
# 3           3             Adun Suites         Gbagada
# 4           4  Hotel Ibis Lagos Ikeja            Ikeja
#
#                                              Address      Cost Property_type  \
# 0    Victoria Island, Lagos - Oniru, Victoria Island   ₦20,000     Apartment
# 1  Lekki Phase 1, Lagos - No. 45 Jay Jay Oladimej...  ₦100,000     Apartment
# 2  Ajao Estate, Lagos - 35/37 Murtala Mohamed Int...   ₦30,000         Hotel
# 3  Gbagada , Lagos - 9, Igbeyinadun Street Off Og...   ₦25,000         Hotel
# 4       Ikeja, Lagos - 23 Toyin Street, Ikeja, Lagos   ₦41,000         Hotel
#
#    Likes Rating Review
# 0    268    NaN    NaN
# 1     38    NaN    NaN
# 2  31079    NaN    NaN
# 3    107    NaN    NaN
# 4  25215    NaN    NaN

# %%
df2.sample(15)
# Out:
#       Unnamed: 0                     Hotel_Name          Location  \
# 345          345           Esteem Royal Suites           Surulere
# 728          728             The Palmview Manor   Victoria Island
# 60            60               MarcoPolo Hotel              Lekki
# 1855        1855                  Abindel Hotel      Oshodi-Isolo
# 2258        2258    Ola Risley Hotel And Suites           Ikorodu
# 2180        2180  Eleshin Dudu Hotel And Suites               NaN
# 1603        1603       Makprote Residence Lagos   Victoria Island
# 826          826                  Bayview Hotel             Ikeja
# 2978        2978           King Solomon Resorts               NaN
# 738          738                 Dam Jay Hotel            Ikorodu
# 522          522           The Governor's Hotel              Ogba
# 107          107     PRIMAL HOTEL & RESORT LTD.             Ikeja
# 2325        2325         Cinderella Guest House              Ogba
# 2208        2208          De Soul Fresher Hotel               NaN
# 2625        2625             Yoris Palace Hotel               NaN
#
#                                                 Address     Cost  \
# 345   Surulere, Lagos - 16, Ibudwu Street, Off Dire ...  ₦12,000
# 728   Victoria Island, Lagos - 2 Tony Anegbode St Of...  ₦25,000
# 60    Lekki, Lagos - 4, Yeni Crescent, Chevy View Es...  ₦30,000
# 1855  Oshodi-Isolo, Lagos - 17 Akande Adebesin Stree...      NaN
# 2258  Ikorodu, Lagos -  Ladugba Estate Sagamu Road, ...      NaN
# 2180         , Lagos - 490 Old Ojo Road, Satellite Town      NaN
# 1603   Victoria Island, Lagos - #2, Simeon Akinlonu ...  ₦72,000
# 826         Ikeja, Lagos - 45 Ajayi Road, Oke Ira, Ogba   ₦4,000
# 2978                                         , Lagos -       NaN
# 738   Ikorodu, Lagos - 27, Alhaji Yusuf Street, Off ...   ₦5,000
# 522    Ogba, Lagos - Plot 294, Adeyemo Akapo Street ...  ₦16,500
# 107   Ikeja, Lagos - No 4, Harold Shodipo Crescent, ...  ₦25,000
# 2325                      Ogba, Lagos - 66, Ijaiye Road      NaN
# 2208   , Lagos - Igbe Road, Opposite Kapo Palace, Ijede      NaN
# 2625                                         , Lagos -       NaN
#
#                       Property_type  Likes         Rating  \
# 345                           Hotel    317  7.8 Very Good
# 728                           Hotel    116            NaN
# 60                            Hotel   1310  7.6 Very Good
# 1855                          Hotel      4            NaN
# 2258    Ola Risley Hotel And Suites      2            NaN
# 2180  Eleshin Dudu Hotel And Suites      2            NaN
# 1603                          Hotel     17            NaN
# 826                    Budget Hotel    441            NaN
# 2978           King Solomon Resorts      1            NaN
# 738                           Hotel     49            NaN
# 522                    Budget Hotel    438            NaN
# 107                           Hotel    754  7.4 Very Good
# 2325         Cinderella Guest House      2            NaN
# 2208          De Soul Fresher Hotel      2            NaN
# 2625             Yoris Palace Hotel      1            NaN
#
#                                                  Review
# 345   <p class="listing-hotels-rating-number">From 4...
# 728                                                 NaN
# 60    <p class="listing-hotels-rating-number">From 6...
# 1855                                                NaN
# 2258                                                NaN
# 2180                                                NaN
# 1603                                                NaN
# 826                                                 NaN
# 2978                                                NaN
# 738                                                 NaN
# 522                                                 NaN
# 107   <p class="listing-hotels-rating-number">From 1...
# 2325                                                NaN
# 2208                                                NaN
# 2625                                                NaN

# %%
df.to_csv("Hotels In Lagos.csv")

# %%
import re
x = "20,000,000 avg/night"
x = "".join(re.findall(r'\d+', x))
print(type(x))
# Out:
# Success

# %%
y = "Book value"
y = y.split(" ")[0]
print(y)
# Out:
# Book
